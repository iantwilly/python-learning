# %%
import math
math.isclose(0.1*3,0.3)
print ("When comparing float values directly we run into precission issues")
print("0.1*3==0.3 :",0.1*3==0.3)
print("To  tackle  this we use the  function math")
# Out:
# True
